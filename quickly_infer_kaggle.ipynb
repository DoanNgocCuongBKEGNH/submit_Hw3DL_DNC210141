# %% [markdown]
# # Run my solution at Kaggle:
# Link: https://www.kaggle.com/competitions/bkai-igh-neopolyp hoặc link dataset này: https://www.kaggle.com/datasets/truongthanh081203/bkai-igh-neopolyp

# %% [markdown]
# # B1: clone my repo

# %%
# !git clone https://github.com/DoanNgocCuongBKEGNH/submit_Hw3DL_DNC210141 # link to my repo
# Out:
# Cloning into 'submit_Hw3DL_DNC210141'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 31 (delta 8), reused 28 (delta 8), pack-reused 0
# Unpacking objects: 100% (31/31), 1.92 MiB | 9.45 MiB/s, done.

# %% [markdown]
# # B2: Thêm my pretrain model vào /kaggle/working/submit_Hw3DL_DNC210141

# %%
# Load best_model.pth from Unet++152resnet(best_at82/200 epochs)

import wandb

wandb.login(key = "c8767797aae76cbcd389ff29929ace1ac3021161")    # key's DoanNgocCuong
run = wandb.init(project = "PolypSegment")

# run = wandb.init()     # Nhập API, cách được đề xuất: https://wandb.ai/doanngoccuong_nh/PolypSegment/artifacts/model/best_model/v1/usage
artifact = run.use_artifact('doanngoccuong_nh/PolypSegment/best_model:v1', type='model')
artifact_dir = artifact.download()

# Hoặc nếu có best model thì upload lên và copy vào /kaggle/working/best_model.pth  (di chuyển đổi tên)
# %cp /kaggle/input/best-mode-v2-pth/best_model_v2.pth /kaggle/working/best_model.pth

# %% [markdown]
# # B3: Di chuyển/Copy submit_model.pth vào /kaggle/working/submit_Hw3DL_DNC210141 và đổi tên thành model.pth

# %%
# !cp /kaggle/input/submit-model-pth/submit_model.pth /kaggle/working/submit_Hw3DL_DNC210141/model.pth

# %% [markdown]
# # B4: Di chuyển vào thư mục submit_Hw3DL_DNC210141

# %%
# %cd /kaggle/working/submit_Hw3DL_DNC210141
# Out:
# /kaggle/working/submit_Hw3DL_DNC210141

# %% [markdown]
# # B5: Cài thư viện

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.8 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for segmentation-models-pytorch from https://files.pythonhosted.org/packages/cb/70/4aac1b240b399b108ce58029ae54bc14497e1bbc275dfab8fd3c84c1e35d/segmentation_models_pytorch-0.3.3-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for timm==0.9.2 from https://files.pythonhosted.org/packages/29/90/94f5deb8d76e24a89813aef95e8809ca8fd7414490428480eda19b133d4a/timm-0.9.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for munch from https://files.pythonhosted.org/packages/56/b3/7c69b37f03260a061883bec0e7b05be7117c1b1c85f5212c72c8c2bc3c8c/munch-4.0.0-py2.py3-none-any.whl.metadata
# ...

# %% [markdown]
# # B6: Run my solution

# %%
# !python infer.py  # args run
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|███████████████████████████████████████| 83.3M/83.3M [00:00<00:00, 216MB/s]
# --- Finish ---200 ...
